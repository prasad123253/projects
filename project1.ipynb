# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad123253/projects/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("/content/student_performance_dataset.csv")

df.head()
# Out:
#    student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0           1    Male               4.0                98.0          6.5
# 1           2  Female               6.3               100.0          5.7
# 2           3    Male               4.9                85.3          7.9
# 3           4    Male               2.6                77.5          8.0
# 4           5    Male               2.2                89.6          4.6
#
#   parental_education internet_access extracurricular_activities part_time_job  \
# 0          Bachelors             Yes                        Yes            No
# 1        High School             Yes                        Yes           Yes
# 2          Bachelors             Yes                         No           Yes
# 3                NaN             Yes                        Yes            No
# 4          Bachelors             Yes                         No           Yes
#
#    previous_grade  final_exam_score final_grade
# ...

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
print(df.shape)
# Out:
# (1000, 12)

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
print(df.columns)
# Out:
# Index(['student_id', 'gender', 'study_time_hours', 'attendance_percent',
#        'sleep_hours', 'parental_education', 'internet_access',
#        'extracurricular_activities', 'part_time_job', 'previous_grade',
#        'final_exam_score', 'final_grade'],
#       dtype='object')

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
df.isnull().sum()
# Out:
# student_id                      0
# gender                          0
# study_time_hours                0
# attendance_percent              0
# sleep_hours                     0
# parental_education            102
# internet_access                 0
# extracurricular_activities      0
# part_time_job                   0
# previous_grade                  0
# final_exam_score                0
# final_grade                     0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.mean(numeric_only=True))
# Out:
# student_id            500.5000
# study_time_hours        3.5707
# attendance_percent     85.0923
# sleep_hours             6.7995
# previous_grade         69.7409
# final_exam_score       83.5435
# dtype: float64

# %%
print(df.median(numeric_only=True))
# Out:
# student_id            500.5
# study_time_hours        3.6
# attendance_percent     85.2
# sleep_hours             6.8
# previous_grade         69.6
# final_exam_score       83.8
# dtype: float64

# %%
print(df.mode(numeric_only=True))
# Out:
#      student_id  study_time_hours  attendance_percent  sleep_hours  \
# 0             1               3.4               100.0          6.5
# 1             2               NaN                 NaN          NaN
# 2             3               NaN                 NaN          NaN
# 3             4               NaN                 NaN          NaN
# 4             5               NaN                 NaN          NaN
# ..          ...               ...                 ...          ...
# 995         996               NaN                 NaN          NaN
# 996         997               NaN                 NaN          NaN
# 997         998               NaN                 NaN          NaN
# 998         999               NaN                 NaN          NaN
# 999        1000               NaN                 NaN          NaN
#
#      previous_grade  final_exam_score
# 0             100.0             100.0
# 1               NaN               NaN
# 2               NaN               NaN
# ...

# %%
print(df.var(numeric_only=True))
# Out:
# student_id            83416.666667
# study_time_hours          2.186138
# attendance_percent       85.945596
# sleep_hours               1.448478
# previous_grade          159.098496
# final_exam_score        106.943161
# dtype: float64

# %%
print(df.std(numeric_only=True))
# Out:
# student_id            288.819436
# study_time_hours        1.478559
# attendance_percent      9.270685
# sleep_hours             1.203527
# previous_grade         12.613425
# final_exam_score       10.341333
# dtype: float64

# %%
print(df.corr(numeric_only=True))
# Out:
#                     student_id  study_time_hours  attendance_percent  \
# student_id            1.000000          0.027615           -0.044651
# study_time_hours      0.027615          1.000000           -0.043712
# attendance_percent   -0.044651         -0.043712            1.000000
# sleep_hours          -0.012304          0.005594            0.034089
# previous_grade        0.011917         -0.035700           -0.014310
# final_exam_score      0.025282          0.567513            0.261872
#
#                     sleep_hours  previous_grade  final_exam_score
# student_id            -0.012304        0.011917          0.025282
# study_time_hours       0.005594       -0.035700          0.567513
# attendance_percent     0.034089       -0.014310          0.261872
# sleep_hours            1.000000        0.000943          0.147811
# previous_grade         0.000943        1.000000          0.406327
# final_exam_score       0.147811        0.406327          1.000000

# %%
Q1 = df.select_dtypes(include='number').quantile(0.25)
Q3 = df.select_dtypes(include='number').quantile(0.75)

IQR = Q3 - Q1

outliers = ((df.select_dtypes(include='number') < (Q1 - 1.5 * IQR)) |
            (df.select_dtypes(include='number') > (Q3 + 1.5 * IQR)))

print(outliers.sum())
# Out:
# student_id            0
# study_time_hours      4
# attendance_percent    6
# sleep_hours           2
# previous_grade        3
# final_exam_score      1
# dtype: int64

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#                     student_id  study_time_hours  attendance_percent  \
# student_id            1.000000          0.027615           -0.044651
# study_time_hours      0.027615          1.000000           -0.043712
# attendance_percent   -0.044651         -0.043712            1.000000
# sleep_hours          -0.012304          0.005594            0.034089
# previous_grade        0.011917         -0.035700           -0.014310
# final_exam_score      0.025282          0.567513            0.261872
#
#                     sleep_hours  previous_grade  final_exam_score
# student_id            -0.012304        0.011917          0.025282
# study_time_hours       0.005594       -0.035700          0.567513
# attendance_percent     0.034089       -0.014310          0.261872
# sleep_hours            1.000000        0.000943          0.147811
# previous_grade         0.000943        1.000000          0.406327
# final_exam_score       0.147811        0.406327          1.000000

# %%
df.sort_values(by="gender")
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 499         500  Female               6.3                87.8          6.2
# 420         421  Female               3.8                87.7          6.7
# 421         422  Female               2.8                90.1          5.8
# 422         423  Female               5.4                69.2          7.9
# 424         425  Female               3.2                80.2          6.7
# ..          ...     ...               ...                 ...          ...
# 454         455    Male               3.4                83.7          7.2
# 455         456    Male               4.5                66.2          5.0
# 458         459    Male               3.7                86.6          7.1
# 414         415    Male               4.9               100.0          7.0
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df[df["gender"] == "Male"]
# Out:
#      student_id gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1   Male               4.0                98.0          6.5
# 2             3   Male               4.9                85.3          7.9
# 3             4   Male               2.6                77.5          8.0
# 4             5   Male               2.2                89.6          4.6
# 6             7   Male               1.5               100.0          5.0
# ..          ...    ...               ...                 ...          ...
# 973         974   Male               3.8                89.1          5.6
# 983         984   Male               2.2                97.4          7.0
# 995         996   Male               2.8                75.4          8.2
# 996         997   Male               6.7                88.4          7.1
# 999        1000   Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df["gender"].value_counts().plot(kind="bar")
plt.title("Gender Distribution")
plt.show()

# %%
df["gender"].value_counts().plot(kind="line", marker="o")
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df["final_exam_score"], bins=10)
plt.title("Final Exam Score Distribution")
plt.xlabel("Final Exam Score")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.hist(df["final_exam_score"], bins=10)
plt.title("Final Exam Score Distribution")
plt.xlabel("Final Exam Score")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["study_time_hours"], df["final_exam_score"])
plt.title("Study Time vs Final Exam Score")
plt.xlabel("Study Time (Hours)")
plt.ylabel("Final Exam Score")
plt.show()

# %%
print("""
       EDA SUMMARY

Load the dataset using pandas.
Perform exploratory data analysis.
Handle missing values and duplicates.
Calculate mean, median, mode, variance, and standard deviation.
Detect and treat outliers.
Analyze correlations between variables.
Create visualizations:
Bar chart
Line chart
Histogram
Scatter plot
Write an EDA summary with key insights.
""")
# Out:
#        EDA SUMMARY
#
# Load the dataset using pandas.
# Perform exploratory data analysis.
# Handle missing values and duplicates.
# Calculate mean, median, mode, variance, and standard deviation.
# Detect and treat outliers.
# Analyze correlations between variables.
# Create visualizations:
# Bar chart
# Line chart
# Histogram
# Scatter plot
# Write an EDA summary with key insights.
